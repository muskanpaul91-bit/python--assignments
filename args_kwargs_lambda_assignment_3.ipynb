# %% [markdown]
# # Python Assignment — *args, **kwargs & Lambda Functions
#
#
# ### Instructions
# - Solve all questions using Python
# - Use functions properly
# - Use loops and conditions wherever required
# - Write optimized and readable code
# - Add proper comments

# %% [markdown]
# # Q1. Find Minimum Number using *args
#
# ## Problem Statement
# Write a Python function using *args to find the minimum number from given arguments.
#
# ## Sample Function Call
# ```python
# minimum(10, 5, 30, 2, 8)
# ```
#
# ## Sample Output
# ```python
# 2
# ```

# %%
def mini(*m):
    min=m[0]
    for i in m:
        if i<min:
            min=i
    return min
print(mini(10,5,30,2,8))
# Out:
# 2

# %% [markdown]
# # Q2. Sum of Even Numbers using *args
#
# ## Problem Statement
# Write a Python function using *args to calculate the sum of all even numbers.
#
# ## Sample Function Call
# ```python
# even_sum(1,2,3,4,5,6)
# ```
#
# ## Sample Output
# ```python
# 12
# ```

# %%
def sum(*s):
    e_sum=0
    for i in s:
        if i%2==0:
            e_sum+=i
    return(e_sum)
print(sum(1,2,3,4,5,6))
# Out:
# 12

# %% [markdown]
# # Q3. User Profile Generator using **kwargs
#
# ## Problem Statement
# Write a Python function using **kwargs to print a user profile dynamically.
#
# ## Sample Function Call
# ```python
# profile(name='Aman', city='Delhi', skill='Python')
# ```
#
# ## Sample Output
# ```python
# name : Aman
# city : Delhi
# skill : Python
# ```

# %%
def profile(**p):
    print(p)
profile(name='Aman',city="Delhi",skill="python")
# Out:
# {'name': 'Aman', 'city': 'Delhi', 'skill': 'python'}

# %% [markdown]
# # Q4. Count Keyword Arguments using **kwargs
#
# ## Problem Statement
# Write a Python function using **kwargs to count total keyword arguments passed.
#
# ## Sample Function Call
# ```python
# details(name='Arjun', age=25, course='DS')
# ```
#
# ## Sample Output
# ```python
# 3
# ```

# %%
def key(**k):
    count=0
    for i in k:
        count+=1
    return (count)
print(key(name='Arjun',age=25,course="DS"))
# Out:
# 3

# %% [markdown]
# # Q5. Lambda Function for String Length
#
# ## Problem Statement
# Write a lambda function to calculate the length of a string.
#
# ## Sample Input
# ```python
# Python
# ```
#
# ## Sample Output
# ```python
# 6
# ```

# %%
length=lambda a:len(a)
length("python")
# Out:
# 6

# %% [markdown]
# # Q6. Sort Dictionary by Value using Lambda
#
# ## Problem Statement
# Write a Python program to sort a dictionary based on values using lambda.
#
# ## Sample Input
# ```python
# {'a':3, 'b':1, 'c':2}
# ```
#
# ## Sample Output
# ```python
# [('b',1), ('c',2), ('a',3)]
# ```

# %%
d= {'a':3, 'b':1, 'c':2}
sort=sorted(d.items(),key=lambda x:x[1])#sort based on values thata why we passed 1
print(sort)
# Out:
# [('b', 1), ('c', 2), ('a', 3)]

# %% [markdown]
# # Q7. Filter Odd Numbers using Lambda
#
# ## Problem Statement
# Write a Python program using lambda and filter() to extract odd numbers from a list.
#
# ## Sample Input
# ```python
# [1,2,3,4,5,6,7]
# ```
#
# ## Sample Output
# ```python
# [1,3,5,7]
# ```

# %%
l=[1,2,3,4,5,6,7]
odd=list(filter(lambda a: a%2!=0,l))
print(odd)
# Out:
# [1, 3, 5, 7]

# %% [markdown]
# # Q8. Convert Strings to Uppercase using Lambda
#
# ## Problem Statement
# Write a Python program using map() and lambda to convert all strings into uppercase.
#
# ## Sample Input
# ```python
# ['python', 'data', 'science']
# ```
#
# ## Sample Output
# ```python
# ['PYTHON', 'DATA', 'SCIENCE']
# ```

# %%
l=['python','data','science']
u=list(map(lambda x:x.upper(),l))
print(u)
# Out:
# ['PYTHON', 'DATA', 'SCIENCE']

# %% [markdown]
# # Q9. Student Marks Analyzer using *args
#
# ## Problem Statement
# Write a Python function using *args to calculate:
# - Total Marks
# - Average Marks
# - Highest Marks
#
# ## Sample Function Call
# ```python
# marks(70,80,90,60)
# ```
#
# ## Sample Output
# ```python
# Total: 300
# Average: 75.0
# Highest: 90
# ```

# %%
def calculate(*c):
    total =0
    higest=c[0]
    for i in c:
        total+=i
        if i>higest:
            higest=i
    average=total/len(c)
    print(f"Total:{total},Average={average},Highest={higest}")
calculate(70,80,90,60)
# Out:
# Total:300,Average=75.0,Highest=90

# %% [markdown]
# # Q10. Dynamic Bill Generator using **kwargs
#
# ## Problem Statement
# Write a Python function using **kwargs to print item names and prices, and calculate total bill amount.
#
# ## Sample Function Call
# ```python
# bill(Shirt=1200, Shoes=2500, Watch=3000)
# ```
#
# ## Sample Output
# ```python
# Shirt : 1200
# Shoes : 2500
# Watch : 3000
# Total Bill : 6700
# ```

# %%
def bill(**b):
    tb=0
    for i in b:
        print(i,':',b[i])
        tb+=b[i]
    print('Total Bill:',tb)
bill(shirt=1200, shoes=2500,Watch=3000)
# Out:
# shirt : 1200
# shoes : 2500
# Watch : 3000
# Total Bill: 6700
